# %%
import pandas as pd

# %%
# sample_1 데이터프레임 변수명으로 sample_1.xlsx 데이터 읽어들인 후 조회하기

# %%
sample_1 = pd.read_excel('C:/STUDY/Web/1day_파이썬기초/files/sample_1.xlsx', skiprows=[0,8,9] )
sample_1
# Out:
#   국적코드  성별    입국객수    전년동기
# 0  A01  남성  106320   85815
# 1  A01  여성  191436  125241
# 2  A31  남성     319     299
# 3  A31  여성      42      54
# 4  A18  남성  158912  124486
# 5  A18  여성  232943  163466

# %%
# 강사님 풀이
file_path = 'C:/STUDY/Web/1day_파이썬기초/files/sample_1.xlsx'
sample_1 = pd.read_excel(file_path, header = 1, skipfooter = 2, usecols = 'A:C')
sample_1
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성  106320
# 1  A01  여성  191436
# 2  A31  남성     319
# 3  A31  여성      42
# 4  A18  남성  158912
# 5  A18  여성  232943

# %%
sample_1.head(3)
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성  106320
# 1  A01  여성  191436
# 2  A31  남성     319

# %%
sample_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적코드    6 non-null      object
#  1   성별      6 non-null      object
#  2   입국객수    6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %%
sample_1.describe()
# Out:
#                 입국객수
# count       6.000000
# mean   114995.333333
# std     98105.752006
# min        42.000000
# 25%     26819.250000
# 50%    132616.000000
# 75%    183305.000000
# max    232943.000000

# %%
sample_1
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성  106320
# 1  A01  여성  191436
# 2  A31  남성     319
# 3  A31  여성      42
# 4  A18  남성  158912
# 5  A18  여성  232943

# %%
# 국적코드와 입국객수 컬럼의 값 조회하기
sample_1[['국적코드','입국객수']]
# Out:
#   국적코드    입국객수
# 0  A01  106320
# 1  A01  191436
# 2  A31     319
# 3  A31      42
# 4  A18  158912
# 5  A18  232943

# %%
# 기준년월이라는 컬럼을 만들고 값은 모두 2019-11로 넣어주세요
sample_1['기준년월'] = '2019-11'
sample_1
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 2  A31  남성     319  2019-11
# 3  A31  여성      42  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
# 필터링
# 성별이 남성인 데이터만 조회하기

# %%
sample_1[sample_1['성별']=='남성']
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 2  A31  남성     319  2019-11
# 4  A18  남성  158912  2019-11

# %%
# 입국객수가 150000 이상인 데이터만 조회하기
sample_1[sample_1['입국객수'] >= 150000]
# Out:
#   국적코드  성별    입국객수     기준년월
# 1  A01  여성  191436  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
# 성별이 여성이고 입국객수가 150000 이상인 데이터 조회
sample_1[(sample_1['성별']=='여성') & (sample_1['입국객수'] >= 150000)]
# Out:
#   국적코드  성별    입국객수     기준년월
# 1  A01  여성  191436  2019-11
# 5  A18  여성  232943  2019-11

# %%
# 국적코드의 값이 A01 또는 A18인 데이터만 조회하기
sample_1[(sample_1['국적코드']=='A01') | (sample_1['국적코드']=='A18')]
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
# isin()함수 : 같은 컬럼내에 여러개 값이 포함되어 있는지 확인할 때 사용
sample_1[sample_1['국적코드'].isin(['A01','A18'])]
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
sample_1[(sample_1['국적코드'].isin(['A01','A18']))== False]
# Out:
#   국적코드  성별  입국객수     기준년월
# 2  A31  남성   319  2019-11
# 3  A31  여성    42  2019-11

# %% [markdown]
# ### 국적코드표 데이터 읽어 들이기

# %%
# sample_codemaster.xlsx 파일 읽어온 후 조회
# 데이터프레임변수 : code_master

# %%
code_master= pd.read_excel('C:/STUDY/Web/1day_파이썬기초/files/sample_codemaster.xlsx')
code_master
# Out:
#   국적코드     국적명
# 0  A01      일본
# 1  A02      대만
# 2  A03      홍콩
# 3  A18      중국
# 4  A19      이란
# 5  A22  우즈베키스탄
# 6  A23   카자흐스탄
# 7  A99  아시아 기타

# %%
sample_1
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 2  A31  남성     319  2019-11
# 3  A31  여성      42  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11

# %%
# 원본에 국적명 통합하기. merge() 사용
sample_1.merge(code_master,left_on='국적코드',right_on='국적코드')
# Out:
#   국적코드  성별    입국객수     기준년월 국적명
# 0  A01  남성  106320  2019-11  일본
# 1  A01  여성  191436  2019-11  일본
# 2  A18  남성  158912  2019-11  중국
# 3  A18  여성  232943  2019-11  중국

# %%
# 강사님 풀이
#1
pd.merge(sample_1, code_master)

#2
pd.merge(left = sample_1,
        right = code_master,
         how = 'inner',
        left_on = '국적코드',
        right_on = '국적코드')
# Out:
#   국적코드  성별    입국객수     기준년월 국적명
# 0  A01  남성  106320  2019-11  일본
# 1  A01  여성  191436  2019-11  일본
# 2  A18  남성  158912  2019-11  중국
# 3  A18  여성  232943  2019-11  중국

# %%
pd.merge(left = sample_1,
        right = code_master,
         how = 'left',
        left_on = '국적코드',
        right_on = '국적코드')
# Out:
#   국적코드  성별    입국객수     기준년월  국적명
# 0  A01  남성  106320  2019-11   일본
# 1  A01  여성  191436  2019-11   일본
# 2  A31  남성     319  2019-11  NaN
# 3  A31  여성      42  2019-11  NaN
# 4  A18  남성  158912  2019-11   중국
# 5  A18  여성  232943  2019-11   중국

# %%
pd.merge(left = sample_1,
        right = code_master,
         how = 'outer',
        left_on = '국적코드',
        right_on = '국적코드')
# Out:
#    국적코드   성별      입국객수     기준년월     국적명
# 0   A01   남성  106320.0  2019-11      일본
# 1   A01   여성  191436.0  2019-11      일본
# 2   A31   남성     319.0  2019-11     NaN
# 3   A31   여성      42.0  2019-11     NaN
# 4   A18   남성  158912.0  2019-11      중국
# 5   A18   여성  232943.0  2019-11      중국
# 6   A02  NaN       NaN      NaN      대만
# 7   A03  NaN       NaN      NaN      홍콩
# 8   A19  NaN       NaN      NaN      이란
# 9   A22  NaN       NaN      NaN  우즈베키스탄
# 10  A23  NaN       NaN      NaN   카자흐스탄
# 11  A99  NaN       NaN      NaN  아시아 기타

# %%
# 데이터프레임변수명 : sample_2
sample_2 = pd.read_excel('C:/STUDY/Web/1day_파이썬기초/files/sample_2.xlsx',header=1, skipfooter=2, usecols='A:C')
sample_2
# Out:
#   국적코드  성별    입국객수
# 0  A01  남성   92556
# 1  A01  여성  163737
# 2  A18  남성  155540
# 3  A18  여성  249023

# %%
sample_2['기준년월'] = '2019-12'

# %%
# 행단위 추가

# %%
sample_total = sample_1.append(sample_2, ignore_index = True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8760\688903991.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sample_total = sample_1.append(sample_2, ignore_index = True)

# %%
sample_total = pd.merge(left = sample_total,
                        right = code_master,
                        how = 'left',
                        left_on = '국적코드',
                        right_on = '국적코드')

# %%
sample_total
# Out:
#   국적코드  성별    입국객수     기준년월  국적명
# 0  A01  남성  106320  2019-11   일본
# 1  A01  여성  191436  2019-11   일본
# 2  A31  남성     319  2019-11  NaN
# 3  A31  여성      42  2019-11  NaN
# 4  A18  남성  158912  2019-11   중국
# 5  A18  여성  232943  2019-11   중국
# 6  A01  남성   92556  2019-12   일본
# 7  A01  여성  163737  2019-12   일본
# 8  A18  남성  155540  2019-12   중국
# 9  A18  여성  249023  2019-12   중국

# %%
sample_total = pd.concat([sample_1,sample_2], ignore_index = True)
sample_total
# Out:
#   국적코드  성별    입국객수     기준년월
# 0  A01  남성  106320  2019-11
# 1  A01  여성  191436  2019-11
# 2  A31  남성     319  2019-11
# 3  A31  여성      42  2019-11
# 4  A18  남성  158912  2019-11
# 5  A18  여성  232943  2019-11
# 6  A01  남성   92556  2019-12
# 7  A01  여성  163737  2019-12
# 8  A18  남성  155540  2019-12
# 9  A18  여성  249023  2019-12

# %%
# 저장하기
# file : sample.xlsx

# %%
file_path = './files/sample.xlsx'
sample_total.to_excel(file_path, index=False)

# %%
# 여러개 파일 한번에 불러오기
# sample 파일 총 24개 읽어들여서
# sample_total 데이터프레임에 합쳐서 넣습니다.
# 최종 컬럼 : 국적코드, 성별, 입국객수, 기준년월, 국적명
# sample_total 조회
# 기준년월 : 각 파일당 2019년 1월 ~ 2021년 12월 값 사용

# 총 데이터 행의 수 계산(검증) : 1개 파일의 행의 수 x 24개 파일

# %%
for i in range(0,24):
    df = pd.read_excel(f'C:/STUDY/Web/2day_판다스기초/files2/sample({i}).xlsx',header=1, skipfooter=2, usecols='A:C')
    df = pd.merge(left = df,
                    right = code_master,
                    how = 'left',
                    left_on = '국적코드',
                    right_on = '국적코드')
    sample_total = pd.concat([sample_total,df], ignore_index = False)

sample_total

# %%
# 위 문장처럼 range(24)로 만들경우 기준년월 적용하려면 list 만들어서 해야함
# ym_list=[]
#for yyyy in range(2019,2021,1):
#   for mm in range(1,13,1):
       #print(str(yyyy)+ '-'+ str(mm).zfill(2))
#        ym_list.append(str(yyyy)+ '-'+ str(mm).zfill(2))


#       sample2['기준년월'] = ym_list[i]    : for문에 적용시키기

# %%
file_path = 'C:/STUDY/Web/sample.xlsx'
sample_total.to_excel(file_path, index=False)

# %%
date1 = int('201901')
date2= int('201912')

for x in range(date1,date2):
    print(x)
# Out:
# 201901
# 201902
# 201903
# 201904
# 201905
# 201906
# 201907
# 201908
# 201909
# 201910
# 201911

# %% [markdown]
# #### 강사님 풀이

# %%
for yyyy in range(2019,2021,1):
    for mm in range(1,13,1):
        print(str(yyyy)+ '-'+ str(mm).zfill(2))  #zfill -자릿수 지정
# Out:
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 2020-04
# 2020-05
# 2020-06
# 2020-07
# 2020-08
# 2020-09
# 2020-10
# 2020-11
# 2020-12

# %%
code_master2 = pd.read_excel('C:/STUDY/Web/2day_판다스기초/files2/sample_codemaster.xlsx')

for i in range(24):
    sample2 = pd.read_excel(f'C:/STUDY/Web/2day_판다스기초/files2/sample({i}).xlsx',header=1, skipfooter=2, usecols='A:C')
    sample2['기준년월'] = ym_list[i]

# %%
code_master2 = pd.read_excel('C:/STUDY/Web/2day_판다스기초/files2/sample_codemaster.xlsx')
i = 0
sample_total = pd.DataFrame()
for yyyy in range(2019,2021,1):
    for mm in range(1,13,1):
        #print(str(yyyy)+ '-'+ str(mm).zfill(2))
        
        sample2 = pd.read_excel('C:/STUDY/Web/2day_판다스기초/files2/sample({}).xlsx'.format(i),header=1, skipfooter=2, usecols='A:C')
        i += 1
        
        sample2['기준년월'] = str(yyyy)+ '-'+ str(mm).zfill(2)
        sample_end = pd.merge(left = sample2, right = code_master2, how = 'left', left_on='국적코드', right_on='국적코드')
        
        sample_total =  pd.concat([sample_total, sample_end], ignore_index=True)
        
sample_total
# Out:
#     국적코드  성별    입국객수     기준년월  국적명
# 0    A01  남성  106320  2019-01   일본
# 1    A01  여성  191436  2019-01   일본
# 2    A31  남성     319  2019-01  NaN
# 3    A31  여성      42  2019-01  NaN
# 4    A18  남성  158912  2019-01   중국
# ..   ...  ..     ...      ...  ...
# 139  A01  여성  191436  2020-12   일본
# 140  A31  남성     319  2020-12  NaN
# 141  A31  여성      42  2020-12  NaN
# 142  A18  남성  158912  2020-12   중국
# 143  A18  여성  232943  2020-12   중국
#
# [144 rows x 5 columns]

# %%
ym_list=[]
for yyyy in range(2019,2021,1):
    for mm in range(1,13,1):
        #print(str(yyyy)+ '-'+ str(mm).zfill(2))
        ym_list.append(str(yyyy)+ '-'+ str(mm).zfill(2))

ym_list
# Out:
# ['2019-01',
#  '2019-02',
#  '2019-03',
#  '2019-04',
#  '2019-05',
#  '2019-06',
#  '2019-07',
#  '2019-08',
#  '2019-09',
#  '2019-10',
#  '2019-11',
#  '2019-12',
#  '2020-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12']
